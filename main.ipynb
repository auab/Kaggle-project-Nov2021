# %% [markdown]
# <a href="https://colab.research.google.com/github/auab/Kaggle-project-Nov2021/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tabular Playground Series - Nov 2021
# This is an exercise proposed by Kaggle to develop ML skills. A dataset is gaven with a label to be classified.
#
# link: https://www.kaggle.com/c/tabular-playground-series-nov-2021

# %% [markdown]
# ## 1. Import libaries and datasets

# %%
# Libraries
#teste
import pandas as pd
from boruta import BorutaPy
from sklearn.linear_model import SGDClassifier
# Datasets
from google.colab import files
uploaded = files.upload()
train_dataset = pd.read_csv('train.csv')
test_dataset = pd.read_csv('test.csv')
# Separate features from values
X_train, y_train = train_dataset.iloc[:,1:-1],train_dataset['target']
X_test = test_dataset.iloc[:,1:]
# Out:
#      <input type="file" id="files-b3289765-b38f-48ba-a4d8-1558cccd93e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3289765-b38f-48ba-a4d8-1558cccd93e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8ac23b49ceb8> in <module>()
#       6 from google.colab import files
#       7 uploaded = files.upload()
# ----> 8 train_dataset = pd.read_csv('train.csv')
#       9 test_dataset = pd.read_csv('test.csv')
#      10 # Separate features from values
#
# ...

# %% [markdown]
# ## 2. Treat the data
#
# First thing to do is a feature selection, this is done here with the Boruta-SHAP algorithm. More about in

# %% [markdown]
# ## 2. Train the model

# %%
sgd_clf = SGDClassifier(loss='log',random_state=42)
sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(loss='log', random_state=42)

# %% [markdown]
# ## 3. Predict the target value

# %%
y_predict = sgd_clf.predict_proba(X_test)
y_proba_1 = [y[1] for y in y_predict]

# %% [markdown]
# ## 4. Save result

# %%
y_predict_df = pd.DataFrame(y_proba_1,columns=['target'])
y_csv_format = pd.concat([test_dataset['id'],y_predict_df],axis=1)
y_csv_format.to_csv('y_predicted.csv',index=False)

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Luis' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
import Boruta
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-f47b626c2603> in <module>
# ----> 1 import Boruta
#
# ModuleNotFoundError: No module named 'Boruta'

# %%
import boruta
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-090822f82244> in <module>
# ----> 1 import boruta
#
# ModuleNotFoundError: No module named 'boruta'

# %%
pip freeze
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Luis' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
# !pip install boruta
# Out:
# ...
#      |████████████████████████████████| 56 kB 3.2 MB/s
# ...
